# %% [markdown]
# # Install Necessary Library

# %%
# !pip install ultralytics roboflow

from ultralytics import YOLO

#ultralytics is for YOLO

#roboflow is to obtain dataset

# %% [markdown]
# # Get Training Data from Roboflow

# %%
# %cd '/data/abhishek/Football_Project/training'

from roboflow import Roboflow
rf = Roboflow(api_key="yIDnbjzgZeNhcOBAKW5O")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# /data/abhishek/Football_Project/training
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 5593.33it/s]

# %% [markdown]
# We need to move train,test,and validation data to another folder inside 'football-players-detection-1' with same folder name. It's a training script demand so need to do it. It can be done manually or using shutil.

# %%
import shutil

shutil.move('/data/abhishek/Football_Project/training/football-players-detection-1/train',
            '/data/abhishek/Football_Project/training/football-players-detection-1/football-players-detection-1/train')

shutil.move('/data/abhishek/Football_Project/training/football-players-detection-1/test',
            '/data/abhishek/Football_Project/training/football-players-detection-1/football-players-detection-1/test')

shutil.move('/data/abhishek/Football_Project/training/football-players-detection-1/valid',
            '/data/abhishek/Football_Project/training/football-players-detection-1/football-players-detection-1/valid')
# Out:
# '/data/abhishek/Football_Project/training/football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5x.pt' with new 'model=yolov5xu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|████████████████████████████████████████| 186M/186M [00:03<00:00, 52.5MB/s]
# Ultralytics YOLOv8.2.70 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# ...

# %%
cd /data/abhishek/football_analysis/
# Out:
# /data/abhishek/football_analysis

# %%
# !git clone https://github.com/abdullahtarek/football_analysis.git
# Out:
# Cloning into 'football_analysis'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 48 (delta 3), reused 2 (delta 2), pack-reused 34
# Unpacking objects: 100% (48/48), 5.97 MiB | 5.55 MiB/s, done.

# %%
# !python main.py
# Out:
# 0: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 8.6ms
# 1: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 8.6ms
# 2: 384x640 1 goalkeeper, 18 players, 3 referees, 8.6ms
# 3: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 8.6ms
# 4: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 8.6ms
# 5: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 8.6ms
# 6: 384x640 1 goalkeeper, 21 players, 3 referees, 8.6ms
# 7: 384x640 1 ball, 1 goalkeeper, 21 players, 3 referees, 8.6ms
# 8: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 8.6ms
# 9: 384x640 1 ball, 1 goalkeeper, 20 players, 3 referees, 8.6ms
# 10: 384x640 1 goalkeeper, 21 players, 3 referees, 8.6ms
# 11: 384x640 1 ball, 1 goalkeeper, 22 players, 3 referees, 8.6ms
# 12: 384x640 21 players, 3 referees, 8.6ms
# 13: 384x640 1 ball, 21 players, 3 referees, 8.6ms
# 14: 384x640 1 ball, 21 players, 3 referees, 8.6ms
# 15: 384x640 1 ball, 20 players, 3 referees, 8.6ms
# ...

# %%
from huggingface_hub import hf_hub_download
model=hf_hub_download('abhi1304/Automated-Football-Analysis','best.pt')
# Out:
# '/home/abhishek/.cache/huggingface/hub/models--abhi1304--Automated-Football-Analysis/snapshots/054af10b27e7663805d8a63b3119bd440aa338a0/best.pt'

# %%
print(model)
# Out:
# /home/abhishek/.cache/huggingface/hub/models--abhi1304--Automated-Football-Analysis/snapshots/054af10b27e7663805d8a63b3119bd440aa338a0/best.pt
